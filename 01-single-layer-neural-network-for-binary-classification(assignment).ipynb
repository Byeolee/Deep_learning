# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generate Dataset

# %%
x1 = np.random.uniform(low=-1.0, high=1.0, size=100)

print(x1.shape)
x1[0:10]
# Out:
# (100,)
# array([ 0.58639978, -0.44464732,  0.51925862,  0.85465397, -0.3429211 ,
#         0.94822008, -0.84811969,  0.02516821, -0.67028391, -0.97052633])

# %%
x2 = np.random.uniform(low=-1.0, high=1.0, size=100)

print(x2.shape)
x2[0:10]
# Out:
# (100,)
# array([ 0.08401476, -0.69171857,  0.98501036,  0.33397401, -0.34467272,
#         0.42438273, -0.95733661, -0.81968077,  0.76801409, -0.34010624])

# %%
y = 0.3 * x1 + 0.5 * x2 + 0.1

print(y.shape)
y[0:10]
# Out:
# (100,)
# array([ 0.31792731, -0.37925348,  0.74828276,  0.5233832 , -0.17521269,
#         0.59665739, -0.63310421, -0.30228992,  0.28292187, -0.36121102])

# %%
plt.scatter(x1, x2, c=y)

# %% [markdown]
# ### Gradient Descent

# %%
num_epoch = 100
learning_rate = 1.0

w1 = np.random.uniform(low=0.0, high=1.0)
w2 = np.random.uniform(low=0.0, high=1.0)
b = np.random.uniform(low=0.0, high=1.0)

for epoch in range(num_epoch):
    y_predict = w1 * x1 + w2 * x2 + b
    
    error = np.abs(y_predict - y).mean()
    
    print("{0:2} error = {1:.6f}".format(epoch, error))
    
    if error < 0.001:
        break

    w1 = w1 - learning_rate * ((y_predict - y) * x1).mean()
    w2 = w2 - learning_rate * ((y_predict - y) * x2).mean()
    b = b - learning_rate * (y_predict - y).mean()

print("----" * 10)
print("w1 = {0:.6f}, w2 = {1:.6f} b = {2:.6f}".format(w1, w2, b))
print("{0:2} error = {1:.6f}".format(epoch, error))
# Out:
#  0 error = 0.341583
#  1 error = 0.178885
#  2 error = 0.109260
#  3 error = 0.067996
#  4 error = 0.043795
#  5 error = 0.028718
#  6 error = 0.019081
#  7 error = 0.012833
#  8 error = 0.008776
#  9 error = 0.006088
# 10 error = 0.004268
# 11 error = 0.003010
# 12 error = 0.002129
# 13 error = 0.001508
# 14 error = 0.001072
# 15 error = 0.000762
# ----------------------------------------
# w1 = 0.299057, w2 = 0.501413 b = 0.100017
# 15 error = 0.000762

# %%
import pandas as pd

y_predict = w1 * x1 + w2 * x2 + b

result = pd.DataFrame({'x1': x1, 'x2': x2, 'y(actual)': y, 'y(predict)': y_predict})

result
# Out:
#           x1        x2  y(actual)  y(predict)
# 0   0.586400  0.084015   0.317927    0.317511
# 1  -0.444647 -0.691719  -0.379253   -0.379795
# 2   0.519259  0.985010   0.748283    0.749203
# 3   0.854654  0.333974   0.523383    0.523067
# 4  -0.342921 -0.344673  -0.175213   -0.175359
# 5   0.948220  0.424383   0.596657    0.596381
# 6  -0.848120 -0.957337  -0.633104   -0.633640
# 7   0.025168 -0.819681  -0.302290   -0.303455
